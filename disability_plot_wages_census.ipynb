# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None
df = pd.read_csv("/Users/rachelp/Documents/disabilities_number_and_wages_data.csv")
df.head()
# Out:
#                                             Unnamed: 0 Unnamed: 1  \
# 0                                                Total      Total
# 1  Management, Business, Science, and Arts Occupations    Summary
# 2      Management, Business, and Financial Occupations    Summary
# 3                               Management Occupations    Summary
# 4                                     Chief executives   Detailed
#
#   Total employed workers Margin of error Workers with a disability  \
# 0            155,041,900         138,778                 9,085,980
# 1             59,155,285         186,745                 2,692,860
# 2             24,008,060          91,850                 1,114,300
# 3             16,331,700          72,089                   767,440
# 4              1,229,375          18,387                    59,150
#
#   Margin of error.1 Percent of workers in occupation with a disability  \
# 0            51,790                                                5.9
# ...

# %%
df.sort_values(by='Percent of workers in occupation with a disability', ascending=False).head(10)
# Out:
#                                                                                   Unnamed: 0  \
# 19                                        Farmers, ranchers, and other agricultural managers
# 234                                         Security guards and gaming surveillance officers
# 298                 Door-to-door sales workers, news and street vendors, and related workers
# 539                                             Automotive and watercraft service attendants
# 526                                                                              Bus drivers
# 552                                                              Packers and packagers, hand
# 321                                                Interviewers, except eligibility and loan
# 252                                Building and Grounds Cleaning and Maintenance Occupations
# 457  Cutting, punching, and press machine setters, operators, and tenders, metal and plastic
# ...
